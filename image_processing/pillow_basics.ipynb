# %%
import PIL as pillow

# %%
from PIL import Image,ImageDraw,ImageFont,ImageFilter,ImageEnhance

# %%
im1 = Image.open('image4.jpg')
print(im1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600 at 0x1ED4A2EEFA0>

# %%
im1 = Image.open('image.jpg')
im2 = Image.open('image2.jpg')
im3 = Image.open('image3.jpg')
im4 = Image.open('image4.jpg')

# %%
print(im4.info)
print(im4.format)
print(im4.mode)
# Out:
# {'jfif': 257, 'jfif_version': (1, 1), 'jfif_unit': 0, 'jfif_density': (1, 1)}
# JPEG
# RGB

# %%
im44=im4.resize((200,200))
im44
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
im44.rotate(45).save('image_rot_45.jpg')

# %%
im2.size
# Out:
# (1280, 719)

# %%
im2.crop((0,0,100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
im2.crop((150,480,400,680))
# Out:
# <PIL.Image.Image image mode=RGB size=250x200>

# %%
im1.size
# Out:
# (512, 512)

# %%
im1=im1.resize(im2.size)

# %%
im1.size,im2.size
# Out:
# ((1280, 719), (1280, 719))

# %%
im1.convert(im2.mode)
print(im1.mode,im2.mode)
print(im1.size,im2.size)
# Out:
# RGB RGB
# (1280, 719) (1280, 719)

# %%
Image.blend(im1,im2,.8).show()

# %%
im1=im1.resize(im2.size)
im3=im3.resize(im2.size)

# %%
im1.convert(im2.mode)
im3.convert(im2.mode)
print(im1.mode,im2.mode)
print(im1.size,im2.size)
# Out:
# RGB RGB
# (1280, 719) (1280, 719)

# %%
Image.blend(im2,im3,.3).show()

# %%
im1
# Out:
# <PIL.Image.Image image mode=RGB size=1280x719>

# %%
logo=Image.open('logo.jpg')
logo
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x360>
